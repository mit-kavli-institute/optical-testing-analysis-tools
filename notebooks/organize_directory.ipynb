# %% [markdown]
# ## Organize some data by header keyword

# %%
import os

from analysis.organization.fits_organizer import organize_fits_files

# %%
# data directory
BOX_PATH = os.path.join(os.getenv("HOME"), "Library", "CloudStorage", "Box-Box")

DATA_DIR = os.path.join(BOX_PATH, "WINTER", "WINTER – Public Data Workspace", "pirt_camera", 
                        "commissioning", 
                        #"20251110",
                        "20251124", "spring"
                        )

# %%
# organize files by header keyword
#organize_fits_files(DATA_DIR, output_dir = "SPRING_20250110_sorted")
organize_fits_files(DATA_DIR, output_dir = "SPRING_20251124_sorted")
# Out:
# Found 207 FITS files
# Organizing files...
#
# ✓ SPRINGCamera_20251125-043320-277.fits -> science/WNTR23bofyo
# ✓ SPRINGCamera_20251125-054616-416.fits -> science/J04391634
# ✓ SPRINGCamera_20251125-092843-530.fits -> focus
# ✓ SPRINGCamera_20251125-033621-165.fits -> science/WNTR24hmgtk
# ✓ SPRINGCamera_20251125-032603-784.fits -> science/WNTR24hmgtk
# ✓ SPRINGCamera_20251125-044814-493.fits -> science/WNTR23bcudq
# ✓ SPRINGCamera_20251125-051514-503.fits -> science/ZTF18acecugr
# ✓ SPRINGCamera_20251125-032312-936.fits -> science/WNTR24hmgtk
# ✓ SPRINGCamera_20251125-054741-289.fits -> science/J04391634
# ✓ SPRINGCamera_20251125-040549-743.fits -> science/WNTR25gyzhl
# ✓ SPRINGCamera_20251125-051932-840.fits -> science/ZTF18acecugr
# ✓ SPRINGCamera_20251125-043743-631.fits -> science/WNTR23bofyo
# ✓ SPRINGCamera_20251125-093138-259.fits -> focus
# ✓ SPRINGCamera_20251125-054242-059.fits -> science/J04391634
# ✓ SPRINGCamera_20251125-052015-600.fits -> science/ZTF18acecugr
# ...
