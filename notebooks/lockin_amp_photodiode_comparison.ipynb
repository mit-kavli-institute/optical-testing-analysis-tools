# %% [markdown]
# # Validating Lock-in Amplifier Photodiode Readout

# %% [markdown]
# ## Test 1: Si PD: Lock-in vs Picoammeter
#
# Test: Using the Si photodiode (1 cm^2), ensure that we can get the same answer for the illumination of a scene with both the lock-in+chopper approach, and the DC picoammeter meausement.

# %%
# Picoammeter Approach:

i_dc_pico_
